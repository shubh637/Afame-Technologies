# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset
df=pd.read_csv("C:\\Users\\TUSHAR SAIN\\Downloads\\HR Data.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Remove unnecessary columns
df =df.drop(['DistanceFromHome','MaritalStatus',"RelationshipSatisfaction"], axis=1)

# %%
# Rename columns
df= df.rename(columns={'EmployeeNumber':'Number_of_employee'})

# %%
#Remove redundant entries (if any)
df =df.drop_duplicates()

# %%
# Sanitize specific columns (e.g., removing leading/trailing whitespaces)
df['Department'] = df['Department'].str.strip()
df['EducationField'] = df['EducationField'].str.strip()

# %%
# Eliminate NaN values
df = df.dropna()

# %%
# Display the first few rows of the cleaned DataFrame
print("First few rows of cleaned HR data:")
df.head()
# Out:
# First few rows of cleaned HR data:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    Education EducationField  EmployeeCount  Number_of_employee  \
# 0          2  Life Sciences              1                   1
# 1          1  Life Sciences              1                   2
# 2          2          Other              1                   4
# 3          4  Life Sciences              1                   5
# 4          1        Medical              1                   7
#
#    EnvironmentSatisfaction  ... PerformanceRating  StandardHours  \
# ...

# %%
# Summary statistics
print("\nSummary statistics:")
df.describe()
# Out:
# Summary statistics:
#                Age    DailyRate    Education  EmployeeCount  \
# count  1470.000000  1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714     2.912925            1.0
# std       9.135373   403.509100     1.024165            0.0
# min      18.000000   102.000000     1.000000            1.0
# 25%      30.000000   465.000000     2.000000            1.0
# 50%      36.000000   802.000000     3.000000            1.0
# 75%      43.000000  1157.000000     4.000000            1.0
# max      60.000000  1499.000000     5.000000            1.0
#
#        Number_of_employee  EnvironmentSatisfaction   HourlyRate  \
# count         1470.000000              1470.000000  1470.000000
# mean          1024.865306                 2.721769    65.891156
# std            602.024335                 1.093082    20.329428
# min              1.000000                 1.000000    30.000000
# 25%            491.250000                 2.000000    48.000000
# ...

# %%
# Count the number of employees in each department
department_counts = df['Department'].value_counts().sort_values(ascending=True)
print("\nNumber of employees in each department:")
department_counts
# Out:
# Number of employees in each department:
# Department
# Human Resources            63
# Sales                     446
# Research & Development    961
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
department_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Employees in Each Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
